# %% [markdown]
# # Before your start:
#
#     Read the README.md file
#     Comment as much as you can and use the resources (README.md file)
#     Happy learning!
#
# *Notes:*
#
# - Solve the questions with python.
#
# - Round the final answer to three decimal places.

# %%
from scipy import stats
import numpy as np
import matplotlib.pyplot as plt
import math

# %% [markdown]
# ## Bernoulli's Distribution
#
# In a basket containing 100 fruits, there are 60 apples and 40 oranges.
#
# A fruit is picked randomly from the basket.
#
# 1. **What is the probability that the fruit is apple?**
# 1. **What is the probability that it is an orange?**

# %%
"""
Calculate:
p = probability that the fruit is an apple 
q = probability that the fruit is an orange
"""


total_fruits = 100
apples = 60
oranges = 40

# Probability of picking an apple
p = apples / total_fruits
q = oranges / total_fruits

print("P(Apple) =", p)
print("P(Orange) =", q)
# Out:
# P(Apple) = 0.6
# P(Orange) = 0.4

# %% [markdown]
# Now we take a random sample of 20 fruits from the basket. After each fruit is taken, a new fruit of the same type is replaced in the basket. Therefore, every time we are taking 1 fruit from 100 fruits.
#
# 1. **What is the probability that the first 5 fruits are all apples?**
#
# 1. **What is the probability that the first 5 fruits are all apples and the next 15 fruits are all oranges?**
#
# You can include the `p` and `q` probabilities you previous calculated in your solution.

# %%
# What is the probability that the first 5 fruits are all apples?
# Probabilities
p = 0.6  # Probability of apple
q = 0.4  # Probability of orange

# This helps us determine the probability of the first 5 fruits being apples
# 1) First 5 apples (exact order)
p_5_apples = p ** 5

# 2) This helps us determine the probability of the first 5 fruits being apples and then 15 oranges
p_5_apples_15_oranges = (p ** 5) * (q ** 15)

print(f"Probability first 5 are all apples: {p_5_apples:.5f}")
print(f"Probability first 5 apples then 15 oranges: {p_5_apples_15_oranges:.10f}")
# Out:
# Probability first 5 are all apples: 0.07776
# Probability first 5 apples then 15 oranges: 0.0000000835

# %% [markdown]
# ## Binomial Distribution
#
# Similar to the above problem, this time again we randomly sample 20 fruits.
#
# **What is the probability that this time the sample contains 5 apples and 15 oranges?**
#
# Please note that this time the order of the fruits being picked does not matter.

# %%
# your solution here

## this is the probability of picking 5 apples and 15 oranges in any order. This represents a  classic binomila distribution problem 
# in order to calculate the probability of picking 5 apples and 15 oranges in any order, we can use the binomial distribution formula:
# we hav already imported the binomial distribution from scipy.stats as binom
#  Parameters
from scipy.stats import binom
#refers to the total number of fruits picked
n = 20      
# refers to the number of apples picked
k = 5      
# refers to the probability of picking an apple
p = 0.6     

# Binomial probability mass function (pmf)
prob_5_apples = binom.pmf(k, n, p)
print(f"Probability of 5 apples and 15 oranges (any order): {prob_5_apples:.6f}")
# Out:
# Probability of 5 apples and 15 oranges (any order): 0.001294

# %%
# your solution here

# %% [markdown]
# In the lesson we also discussed CDF (cumulative distribution function). In the context of the above problem, **what is the probability that less than 5 fruits picked are apples?**
#
# Write the formula and calculate the probability below.

# %%
# your code here
#Less than 5 apples means we need to calculate the cumulative distribution function (CDF) for k = 4
# This gives us the probability of getting 0, 1, 2, 3, or 4 apples in 20 trials.
# We can use the binomial distribution CDF
# parameters
# refers to the total number of trials (fruits picked)
n = 20
# refers to the probability of picking an apple
p = 0.6       
k = 4         # "less than 5" means k <= 4

# CDF calculation
prob_less_than_5 = binom.cdf(k, n, p)
print(f"Probability of less than 5 apples: {prob_less_than_5:.4f}")
# Out:
# Probability of less than 5 apples: 0.0003

# %% [markdown]
# <!-- **Plot the PDF (probability distributiom function) for the above binomial distribution.** -->
#
# **Plot the Probability Mass Function (PMF) for the above binomial distribution.**
#
# *Hint: The range of x in a binomial distribution is from `0` to `n`.*

# %%
# your code here
# Please label the axes and give a title to the plot 

# Parameters
n = 20       # total number of picks
p = 0.6      # probability of apple in one pick

# Range of possible apple counts
x = np.arange(0, n+1)

# PMF values
pmf_values = binom.pmf(x, n, p)

# Plot PMF
plt.bar(x, pmf_values, color='skyblue', edgecolor='black')
plt.title('PMF - Binomial Distribution (n=20, p=0.6)')
plt.xlabel('Number of Apples (x)')
plt.ylabel('Probability')
plt.xticks(x)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ## Poisson Distribution
#
# In this challenge you are required to use the Math library in python to solve the problems.
#
# In the UEFA champions league tournament, the average number of goals scored in a match is 2.3.
#
# **What is the probability that the number of goals scored in a match is 5?**
#
# *Hint: Use the exp() in the math library*
#
# And to calculate the factorial, you can use the following code:
#
# ```python
# import math
# math.factorial(n) # n is the number you want to find the factorial of
# ```

# %%
# your code here 
import math
math.factorial(n)

# Parameters from the problem
n = 20       # total number of picks
p = 0.6      # probability of apple in one pick
k = 5        # number of apples picked
lmbda = 2.3  
k = 5       

# Poisson probability mass function
# The Poisson distribution is used for modeling the number of events in a fixed interval of time
# or space, given a known average rate (lambda).
# The formula for the Poisson probability mass function is:
# P(X = k) = (e^(-λ) * λ^k) / k!
# where:
# - λ (lambda) is the average number of events in the interval
# - k is the number of events we want to find the probability for
# - e is the base of the natural logarithm (approximately 2.71828)
# - k! is the factorial of k
# In this case, we want to find the probability of exactly k goals scored in a match
# using the Poisson distribution with a given lambda (lmbda).
# Calculate the Poisson probability
poisson_prob = (math.exp(-lmbda) * (lmbda ** k)) / math.factorial(k)

print(f"Probability of exactly {k} goals: {poisson_prob:.4f}")
# Out:
# Probability of exactly 5 goals: 0.0538

# %% [markdown]
# **Draw a poisson probability distribution plot for the number of goals to be between 0 to 10.**

# %%
# your code here
# Please label the axes and give a title to the plot 

# Parameters
# Parameters
lambda_ = 2.3  # average goals per match
x_values = list(range(0, 11))  # from 0 to 10 goals

# Poisson PMF formula
poisson_pmf = [(math.exp(-lambda_) * (lambda_**x) / math.factorial(x)) for x in x_values]

# Plot
plt.bar(x_values, poisson_pmf, color='skyblue', edgecolor='black')
plt.title("Poisson Probability Distribution (λ=2.3)")
plt.xlabel("Number of Goals")
plt.ylabel("Probability")
plt.xticks(x_values)
plt.show()
